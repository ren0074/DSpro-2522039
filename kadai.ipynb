# %% [markdown]
# ## 最終課題

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import time

# 起点 URL
base_url = "https://www.musashino-u.ac.jp/"  # 武蔵野大学Webサイトのトップページ

# 辿ったURLとタイトルを保存するための辞書
url_title_dict = {}

# リンクを巡回するためのセット
to_visit = set([base_url]) 
visited = set() 

# ロボット除けとユーザーエージェントの設定
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'ja,en-US;q=0.9,en;q=0.8',
    'Accept-Encoding': 'gzip, deflate, br'
}

CRAWL_DELAY_SECONDS = 0.8

def normalize_url(url):
    """
    URLを正規化する関数。
    重複を避けるため、クエリパラメータとフラグメントを除去します。
    """
    parsed = urlparse(url)
    return urljoin(f"{parsed.scheme}://{parsed.netloc}", parsed.path)

def get_title(url):
    """ページの<title>を取得する関数"""
    try:
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status() # HTTPエラー（4xx, 5xx）があれば例外を発生させる
        time.sleep(CRAWL_DELAY_SECONDS) # 各リクエスト後に待機
        soup = BeautifulSoup(response.text, "html.parser")
        # タイトルがNoneでないことと、文字列であることを確認し、空白を除去
        title = soup.title.string.strip() if soup.title and soup.title.string else "No Title"
        # 連続する空白等を正規化 (オプション)
        return ' '.join(title.split())
    except requests.exceptions.RequestException as e:
        print(f"Error accessing {url}: {e}")
        return f"Fetching Error: {type(e).__name__}"
    except Exception as e:
        print(f"Error processing {url}: {e}")
        return f"Processing Error: {type(e).__name__}"

def find_links(url):
    """指定したURLに存在する、同一ドメイン内のリンクをすべて取得"""
    links = set()
    try:
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status() # HTTPエラー（4xx, 5xx）があれば例外を発生させる
        time.sleep(CRAWL_DELAY_SECONDS) # 各リクエスト後に待機
        soup = BeautifulSoup(response.text, "html.parser")

        for anchor in soup.find_all("a", href=True):
            href = anchor["href"]

            # JavaScriptリンクやアンカーリンク（ページ内ジャンプ）を除外
            if href.startswith("javascript:") or href.startswith("#"):
                continue

            # 絶対URLに変換
            absolute_url = urljoin(url, href)

            # 正規化
            normalized_absolute_url = normalize_url(absolute_url)

            # ドメインチェック
            base_hostname = urlparse(base_url).hostname
            link_hostname = urlparse(normalized_absolute_url).hostname

            # ホスト名が base_hostname またはそのサブドメインであるかチェック
            if link_hostname and (link_hostname == base_hostname or link_hostname.endswith('.' + base_hostname)):
                 links.add(normalized_absolute_url)

    except requests.exceptions.RequestException as e:
        print(f"Error fetching links from {url}: {e}")
    except Exception as e:
        print(f"Error processing links from {url}: {e}")
    return links

# メインループ: リンクを辿る (BFS)
while to_visit:
    # 巡回するURLを to_visit から一つ取り出す
    current_url = to_visit.pop()

    # 既に訪問済みならスキップ (これがないと無限ループや重複クロールが発生)
    if current_url in visited:
        continue

    # 訪問済みリストに加える
    visited.add(current_url)
    print(f"Visiting: {current_url} (Remaining to visit: {len(to_visit)}, Visited: {len(visited)})")

    # URLの<title>を辞書に格納
    page_title = get_title(current_url)
    url_title_dict[current_url] = page_title

    # ページ内のリンクを探索
    new_links = find_links(current_url)

    to_visit.update(new_links - visited)

# 結果を表示
print("\n--- Crawling Completed ---")
print("Total URLs found:", len(url_title_dict))
for url, title in url_title_dict.items():
    print(f"URL: {url}\nTitle: {title}\n---")
# Out:
# Visiting: https://www.musashino-u.ac.jp/ (Remaining to visit: 0, Visited: 1)
# Visiting: https://www.musashino-u.ac.jp/international/international-students/ (Remaining to visit: 98, Visited: 2)
# Visiting: https://www.musashino-u.ac.jp/admission/short_term_course/ (Remaining to visit: 137, Visited: 3)
# Visiting: https://www.musashino-u.ac.jp/news/detail/20251104-7308.html (Remaining to visit: 168, Visited: 4)
# Visiting: https://www.musashino-u.ac.jp/admission/event/ (Remaining to visit: 179, Visited: 5)
# Visiting: https://www.musashino-u.ac.jp/basic/buddhist_studies/ (Remaining to visit: 179, Visited: 6)
# Visiting: https://www.musashino-u.ac.jp/prospective-students.html (Remaining to visit: 192, Visited: 7)
# Visiting: https://www.musashino-u.ac.jp/news/2021/ (Remaining to visit: 201, Visited: 8)
# Visiting: https://www.musashino-u.ac.jp/admission/student_support_site/ (Remaining to visit: 228, Visited: 9)
# Visiting: https://www.musashino-u.ac.jp/guide/profile/media/ (Remaining to visit: 251, Visited: 10)
# Visiting: https://www.musashino-u.ac.jp/basic/buddhist_studies/buddhist_view.html (Remaining to visit: 292, Visited: 11)
# Visiting: https://www.musashino-u.ac.jp/international/events/supporter.html (Remaining to visit: 291, Visited: 12)
# Visiting: https://www.musashino-u.ac.jp/academics/faculty/global_studies/global_communication/ (Remaining to visit: 291, Visited: 13)
# Visiting: https://www.musashino-u.ac.jp/admission/faculty/event/weboc/ (Remaining to visit: 306, Visited: 14)
# Visiting: https://www.musashino-u.ac.jp/international/events/ (Remaining to visit: 311, Visited: 15)
# Visiting: https://www.musashino-u.ac.jp/research/interview/15_hurukawa/ (Remaining to visit: 310, Visited: 16)
# Visiting: https://www.musashino-u.ac.jp/news/2023/index.php (Remaining to visit: 338, Visited: 17)
# Visiting: https://www.musashino-u.ac.jp/guide/information/students.html (Remaining to visit: 345, Visited: 18)
# Visiting: https://www.musashino-u.ac.jp/academics/teachers_license/ (Remaining to visit: 345, Visited: 19)
# Visiting: https://www.musashino-u.ac.jp/happiness_creators/no026.html (Remaining to visit: 349, Visited: 20)
# Visiting: https://www.musashino-u.ac.jp/guide/campus/ariake_campus.html (Remaining to visit: 350, Visited: 21)
# Visiting: https://www.musashino-u.ac.jp/basic/endowment_course.html (Remaining to visit: 350, Visited: 22)
# Visiting: https://www.musashino-u.ac.jp/student-life/life/ (Remaining to visit: 349, Visited: 23)
# Visiting: https://www.musashino-u.ac.jp/academics/ (Remaining to visit: 385, Visited: 24)
# Visiting: https://www.musashino-u.ac.jp/guide/profile/history.html (Remaining to visit: 414, Visited: 25)
# Visiting: https://www.musashino-u.ac.jp/international/gc_portal/ (Remaining to visit: 413, Visited: 26)
# Visiting: https://www.musashino-u.ac.jp/student-life/learning/course/faq.html (Remaining to visit: 414, Visited: 27)
# Visiting: https://www.musashino-u.ac.jp/student-life/application/procedure.html (Remaining to visit: 414, Visited: 28)
# Visiting: https://www.musashino-u.ac.jp/student-life/career/internship.html (Remaining to visit: 417, Visited: 29)
# Visiting: https://www.musashino-u.ac.jp/admission/faculty/event/weboc/dijesto.html (Remaining to visit: 417, Visited: 30)
# Visiting: https://www.musashino-u.ac.jp/basic/policies/curriculumpolicy.html (Remaining to visit: 419, Visited: 31)
# Visiting: https://www.musashino-u.ac.jp/academics/faculty
E3%83%AC%E3%83%9B%E3%82%9A%E3%83%BC%E3%83%88%EF%BC%9A%E3%80%8C%E5%85%A8%E5%93%A1%E7%95%99%E5%AD%A6%E3%80%8D%E3%82%92%E9%80%9A%E3%81%97%E3%82%99%E3%81%9F%E5%AD%A6%E7%94%9F%E3%81%AE%E6%88%90%E9%95%B7%E3%81%A8%E3%83%95%E3%82%9A%E3%83%AD%E3%82%BB%E3%82%B9%E3%82%92%E5%8F%AF%E8%A6%96%E5%8C%96.pdf (Remaining to visit: 2366, Visited: 3476)
# Visiting: http://www.musashino-u.ac.jp/research/pdf/20170912_Nishimura.pdf (Remaining to visit: 2365, Visited: 3477)
# Visiting: http://www.musashino-u.ac.jp/research/laboratory/literature.html (Remaining to visit: 2364, Visited: 3478)
# Visiting: https://www.musashino-u.ac.jp/student-life/%E5%8B%9F%E9%9B%86%E8%A6%81%E9%A0%85%EF%BC%882025%E5%B9%B4%E6%AD%A6%E8%94%B5%E9%87%8E%E5%A4%A7%E5%AD%A6%E5%8D%92%E6%A5%AD%E7%94%9F%E7%89%B9%E5%88%A5%E5%A5%A8%E5%8A%B1%E9%87%91%EF%BC%89_2.pdf (Remaining to visit: 2363, Visited: 3479)
# Visiting: http://www.musashino-u.ac.jp/guide/facility/ (Remaining to visit: 2362, Visited: 3480)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 106
#     103 print(f"Visiting: {current_url} (Remaining to visit: {len(to_visit)}, Visited: {len(visited)})")
#     105 # URLの<title>を辞書に格納
# --> 106 page_title = get_title(current_url)
#     107 url_title_dict[current_url] = page_title
#     109 # ページ内のリンクを探索
#
# Cell In[14], line 42, in get_title(url)
#      40 response.raise_for_status() # HTTPエラー（4xx, 5xx）があれば例外を発生させる
#      41 time.sleep(CRAWL_DELAY_SECONDS) # 各リクエスト後に待機
# ---> 42 soup = BeautifulSoup(response.text, "html.parser")
#      43 # タイトルがNoneでないことと、文字列であることを確認し、空白を除去
#      44 title = soup.title.string.strip() if soup.title and soup.title.string else "No Title"
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/bs4/__init__.py:473, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     471 self.builder.initialize_soup(self)
#     472 try:
# --> 473     self._feed()
#     474     success = True
#     475     break
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/bs4/__init__.py:658, in BeautifulSoup._feed(self)
#     655 self.builder.reset()
#     657 if self.markup is not None:
# --> 658     self.builder.feed(self.markup)
#     659 # Close out any unfinished strings and close all the open tags.
#     660 self.endData()
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/bs4/builder/_htmlparser.py:467, in HTMLParserTreeBuilder.feed(self, markup)
#     464 parser = BeautifulSoupHTMLParser(self.soup, *args, **kwargs)
#     466 try:
# --> 467     parser.feed(markup)
#     468     parser.close()
#     469 except AssertionError as e:
#     470     # html.parser raises AssertionError in rare cases to
#     471     # indicate a fatal problem with the markup, especially
#     472     # when there's an error in the doctype declaration.
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/html/parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/html/parser.py:170, in HTMLParser.goahead(self, end)
#     168 if startswith('<', i):
#     169     if starttagopen.match(rawdata, i): # < + letter
# --> 170         k = self.parse_starttag(i)
#     171     elif startswith("</", i):
#     172         k = self.parse_endtag(i)
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/html/parser.py:344, in HTMLParser.parse_starttag(self, i)
#     342     self.handle_startendtag(tag, attrs)
#     343 else:
# --> 344     self.handle_starttag(tag, attrs)
#     345     if tag in self.CDATA_CONTENT_ELEMENTS:
#     346         self.set_cdata_mode(tag)
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/bs4/builder/_htmlparser.py:182, in BeautifulSoupHTMLParser.handle_starttag(self, name, attrs, handle_empty_element)
#     180 else:
#     181     sourceline = sourcepos = None
# --> 182 tag = self.soup.handle_starttag(
#     183     name, None, None, attr_dict, sourceline=sourceline, sourcepos=sourcepos
#     184 )
#     185 if tag and tag.is_empty_element and handle_empty_element:
#     186     # Unlike other parsers, html.parser doesn't send separate end tag
#     187     # events for empty-element tags. (It's handled in
#    (...)
#     193     # don't want handle_endtag() to cross off any previous end
#     194     # events for tags of this name.
#     195     self.handle_endtag(name, check_already_closed=False)
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/bs4/__init__.py:1032, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#    1029 # Assume that this is either Tag or a subclass of Tag. If not,
#    1030 # the user brought type-unsafety upon themselves.
#    1031 tag_class = cast(Type[Tag], tag_class)
# -> 1032 tag = tag_class(
#    1033     self,
#    1034     self.builder,
#    1035     name,
#    1036     namespace,
#    1037     nsprefix,
#    1038     attrs,
#    1039     self.currentTag,
#    1040     self._most_recent_element,
#    1041     sourceline=sourceline,
#    1042     sourcepos=sourcepos,
#    1043     namespaces=namespaces,
#    1044 )
#    1045 if tag is None:
#    1046     return tag
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/bs4/element.py:1706, in Tag.__init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags, interesting_string_types, namespaces)
#    1704     self.known_xml = is_xml
#    1705 self.contents: List[PageElement] = []
# -> 1706 self.setup(parent, previous)
#    1707 self.hidden = False
#    1709 if builder is None:
#    1710     # In the absence of a TreeBuilder, use whatever values were
#    1711     # passed in here. They're probably None, unless this is a copy of some
#    1712     # other tag.
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/bs4/element.py:423, in PageElement.setup(self, parent, previous_element, next_element, previous_sibling, next_sibling)
#     420     previous_sibling = self.parent.contents[-1]
#     422 self.previous_sibling = previous_sibling
# --> 423 if self.previous_sibling is not None:
#     424     self.previous_sibling.next_sibling = self
#
# KeyboardInterrupt:
